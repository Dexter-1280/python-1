# %%
s1="hello"
s2='world'
s3="""This spans mult
iple lines"""
print(s1,s2)
print(s3)

print('Line1\nline2')
print('Name\tAlice')
print('She said ,\hello\'')
# Out:
# hello world
# This spans mult
# iple lines
# Line1
# line2
# Name	Alice
# She said ,\hello'

# %%
s='Python'
print(s[0])
print(s[-1])
print(s[1:4])
print(s[::2])
print(s[::-1])
# Out:
# P
# n
# yth
# Pto
# nohtyP

# %%
s='hello word'
print(s.upper())
print(s.capitalize())
print(s.replace('world','python'))
print(s.split())
print(len(s))
print('world' in s)
print('  space  '.strip())
print(s[::-1])
# Out:
# HELLO WORD
# Hello word
# hello word
# ['hello', 'word']
# 10
# False
# space
# drow olleh

# %%
name='alice'
age=20
print(f'My name is {name}, and I am {age} year old.')
print('My name is {} and I am {} year old'.format(name,age))
print('{city} is the captial of {country}'.format (city='delhi',country='India'))
# Out:
# My name is alice, and I am 20 year old.
# My name is alice and I am 20 year old
# delhi is the captial of India

# %%
str='Hello world'
count=0
for letter in str:
    print(letter)
    print(count,'Letter found')
    
    if(letter=='0'):
        count+=1
# Out:
# H
# 0 Letter found
# e
# 0 Letter found
# l
# 0 Letter found
# l
# 0 Letter found
# o
# 0 Letter found
#
# 0 Letter found
# w
# 0 Letter found
# o
# 0 Letter found
# r
# 0 Letter found
# l
# 0 Letter found
# d
# 0 Letter found

# %%
str='RAMDEOBABA COLLEGE'

list_enumerate=list(enumerate(str))
print('list(enumerate(str)=',list_enumerate)

print('len(str)=',len(str))
# Out:
# list(enumerate(str)= [(0, 'R'), (1, 'A'), (2, 'M'), (3, 'D'), (4, 'E'), (5, 'O'), (6, 'B'), (7, 'A'), (8, 'B'), (9, 'A'), (10, ' '), (11, 'C'), (12, 'O'), (13, 'L'), (14, 'L'), (15, 'E'), (16, 'G'), (17, 'E')]
# len(str)= 18

# %%
str='HH'
print(str.casefold())
print(str.isnumeric())
# Out:
# hh

# %%
empty=[]
numbers=[1,2,3,4,5]
mixed=[1,'hello',3.14,True]
nested=[1,[2,3],[4,5]]

print(numbers)
print(mixed)
print(nested[1])
print(nested[1][0])
# Out:
# [1, 2, 3, 4, 5]
# [1, 'hello', 3.14, True]
# [2, 3]
# 2

# %%
fruits=['apple','banana','cherry','date','elderberry']
print(fruits[0])
print(fruits[-1])
print(fruits[1:3])
print(fruits[::2])
print(fruits[::-1])
# Out:
# apple
# elderberry
# ['banana', 'cherry']
# ['apple', 'cherry', 'elderberry']
# ['elderberry', 'date', 'cherry', 'banana', 'apple']

# %%
nums=[10,20,30]

nums[1]=99
print(nums)

nums.append(40)
print(nums)

nums.insert(1,55)
print(nums)

nums.remove(99)
print(nums)

nums.pop()
print(nums)
# Out:
# [10, 99, 30]
# [10, 99, 30, 40]
# [10, 55, 99, 30, 40]
# [10, 55, 30, 40]
# [10, 55, 30]

# %%
nums=[3,1,4,5,6,6,537,75]

print(len(nums))
print(sum(nums))
print(min(nums))
print(max(nums))
print(nums.count(1))
print(nums.index(5))

nums.sort()
print(nums)

nums.reverse()
print(nums)
# Out:
# 8
# 637
# 1
# 537
# 1
# 3
# [1, 3, 4, 5, 6, 6, 75, 537]
# [537, 75, 6, 6, 5, 4, 3, 1]

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
print(a*3)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
empty=()
numbers=(1,2,3)
mixed=(1,'hello',3.14)
single=(42,)
no_paren=10,20,30
print(numbers)
print(type(single))
print(type(42))
print(no_paren)
# Out:
# (1, 2, 3)
# <class 'tuple'>
# <class 'int'>
# (10, 20, 30)

# %%
t=('a','b','c','d','e')
print(t[0])
print(t[-1])
print(t[1:3])
print(t[::-1])
# Out:
# a
# e
# ('b', 'c')
# ('e', 'd', 'c', 'b', 'a')

# %%
t=(1,2,3)
t2=t+(4,5)
print(t2)
print((0,)*5)

t3=(1,[2,3],4)
t3[1][0]=99
print(t3)
# Out:
# (1, 2, 3, 4, 5)
# (0, 0, 0, 0, 0)
# (1, [99, 3], 4)

# %%
point=(10,20,30)
x,y,z=point
print(x,y,z)

a,b=5,10
a,b=b,a
print(a,b)
# Out:
# 10 20 30
# 10 5

# %%
t=('a','p','p','l')
print(t.count('p'))
print(t.index('l'))

print('a' in t)
print('z' in t)
nums=(4,2,9,1,7)
print(len(nums),min(nums),max(nums))
# Out:
# 2
# 3
# True
# False
# 5 1 9
